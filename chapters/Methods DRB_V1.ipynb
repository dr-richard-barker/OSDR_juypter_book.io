# %% [markdown]
# # AI/ML methods notebook

# %% [markdown]
# # install Python packages
# This notebook is equipped with a dedicated login shell, tailored to the environment in which it is executed.
# If you are utilizing your personal compute system, such as a laptop, the login corresponds to your individual compute system login.
# Conversely, when running this notebook on Google Colab, the login is attributed to the root user.
# The initiation of Linux shell commands within Jupyter notebook code cells is denoted by a preceding exclamation point (!).
#
# In the code cell below, the provided pip commands are employed to install a range of Python libraries essential for the tasks covered in this notebook.
# It's worth noting that additional Python libraries are automatically installed within our virtual environment.

# %%
pip install pybiomart
# Out:
# Collecting pybiomart
#   Downloading pybiomart-0.2.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting future (from pybiomart)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pandas (from pybiomart)
#   Downloading pandas-2.2.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (19 kB)
# Collecting requests (from pybiomart)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-cache (from pybiomart)
#   Downloading requests_cache-1.2.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas->pybiomart) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas->pybiomart) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas->pybiomart) (2023.3)
# Collecting tzdata>=2022.7 (from pandas->pybiomart)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting charset-normalizer<4,>=2 (from requests->pybiomart)
#   Downloading charset_normalizer-3.3.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->pybiomart)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests->pybiomart) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests->pybiomart) (2023.7.22)
# Collecting attrs>=21.2 (from requests-cache->pybiomart)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting cattrs>=22.2 (from requests-cache->pybiomart)
#   Downloading cattrs-23.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests-cache->pybiomart) (3.5.1)
# Collecting url-normalize>=1.4 (from requests-cache->pybiomart)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting exceptiongroup>=1.1.1 (from cattrs>=22.2->requests-cache->pybiomart)
#   Downloading exceptiongroup-1.2.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting typing-extensions!=4.6.3,>=4.1.0 (from cattrs>=22.2->requests-cache->pybiomart)
#   Downloading typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: six>=1.5 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas->pybiomart) (1.16.0)
# Downloading pybiomart-0.2.0-py3-none-any.whl (10 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.2.2-cp310-cp310-macosx_10_9_x86_64.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 2.8 MB/s eta 0:00:0000:0100:01
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 1.2 MB/s eta 0:00:0000:01
# Downloading requests_cache-1.2.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 938.2 kB/s eta 0:00:000:00:01
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Downloading cattrs-23.2.3-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading charset_normalizer-3.3.2-cp310-cp310-macosx_10_9_x86_64.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.5/122.5 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Downloading exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Installing collected packages: url-normalize, tzdata, typing-extensions, idna, future, exceptiongroup, charset-normalizer, attrs, requests, pandas, cattrs, requests-cache, pybiomart
# Successfully installed attrs-23.2.0 cattrs-23.2.3 charset-normalizer-3.3.2 exceptiongroup-1.2.1 future-1.0.0 idna-3.7 pandas-2.2.2 pybiomart-0.2.0 requests-2.31.0 requests-cache-1.2.0 typing-extensions-4.11.0 tzdata-2024.1 url-normalize-1.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 377.9 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn --no-cache
# !pip install scanpy --no-cache
# !pip install gseapy --no-cache
# !pip install pydeseq2 --no-cache
# !pip install pybiomart==0.1 --no-cache
# !pip install mygene --no-cache
# !pip install sklearn_som  --no-cache
# !pip install pandas --no-cache
# !pip install numpy --no-cache
# !pip install matplotlib --no-cache
# !pip install sklearn-som --no-cache
# !pip install pyDeseq2 --no-cache
# !pip install Ensembl_converter --no-cache
# !pip install mygene --no-cache
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn) (1.24.3)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 723.0 kB/s eta 0:00:00a 0:00:01
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.2-cp310-cp310-macosx_10_9_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 11.7 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 17.1 MB/s eta 0:00:00
# Downloading scipy-1.13.0-cp310-cp310-macosx_10_9_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 12.5 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.0 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.4.0
# Collecting scanpy
#   Downloading scanpy-1.10.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting anndata>=0.8 (from scanpy)
#   Downloading anndata-0.10.7-py3-none-any.whl.metadata (6.6 kB)
# Collecting h5py>=3.1 (from scanpy)
#   Downloading h5py-3.11.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (1.4.0)
# Collecting legacy-api-wrap>=1.4 (from scanpy)
#   Downloading legacy_api_wrap-1.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting matplotlib>=3.6 (from scanpy)
#   Downloading matplotlib-3.8.4-cp310-cp310-macosx_10_12_x86_64.whl.metadata (5.8 kB)
# Collecting natsort (from scanpy)
#   Downloading natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting networkx>=2.7 (from scanpy)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting numba>=0.56 (from scanpy)
#   Downloading numba-0.59.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (1.24.3)
# Requirement already satisfied: packaging>=21.3 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from scanpy) (23.1)
# Requirement already satisfied: pandas>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (2.2.2)
# Collecting patsy (from scanpy)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting pynndescent>=0.5 (from scanpy)
#   Downloading pynndescent-0.5.12-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: scikit-learn>=0.24 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (1.4.2)
# Requirement already satisfied: scipy>=1.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scanpy) (1.13.0)
# Collecting seaborn>=0.13 (from scanpy)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting session-info (from scanpy)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting statsmodels>=0.13 (from scanpy)
#   Downloading statsmodels-0.14.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (9.2 kB)
# Collecting tqdm (from scanpy)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 648.6 kB/s eta 0:00:00 0:00:01
# Collecting umap-learn!=0.5.0,>=0.5 (from scanpy)
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Collecting array-api-compat!=1.5,>1.4 (from anndata>=0.8->scanpy)
#   Downloading array_api_compat-1.6-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: exceptiongroup in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anndata>=0.8->scanpy) (1.2.1)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.6->scanpy)
#   Downloading contourpy-1.2.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.6->scanpy)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.6->scanpy)
#   Downloading fonttools-4.51.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.6->scanpy)
#   Downloading kiwisolver-1.4.5-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# Collecting pillow>=8 (from matplotlib>=3.6->scanpy)
#   Downloading pillow-10.3.0-cp310-cp310-macosx_10_10_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.6->scanpy)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from matplotlib>=3.6->scanpy) (2.8.2)
# Collecting llvmlite<0.43,>=0.42.0dev0 (from numba>=0.56->scanpy)
#   Downloading llvmlite-0.42.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas>=1.5->scanpy) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.5->scanpy) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn>=0.24->scanpy) (3.4.0)
# Requirement already satisfied: six in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from patsy->scanpy) (1.16.0)
# Collecting stdlib_list (from session-info->scanpy)
#   Downloading stdlib_list-0.10.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading scanpy-1.10.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Downloading anndata-0.10.7-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 kB 14.7 MB/s eta 0:00:00
# Downloading h5py-3.11.0-cp310-cp310-macosx_10_9_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 6.6 MB/s eta 0:00:0000:0100:01mm
# Downloading legacy_api_wrap-1.4-py3-none-any.whl (15 kB)
# Downloading matplotlib-3.8.4-cp310-cp310-macosx_10_12_x86_64.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 5.7 MB/s eta 0:00:0000:0100:01
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.7 MB/s eta 0:00:00a 0:00:01
# Downloading numba-0.59.1-cp310-cp310-macosx_10_9_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 4.5 MB/s eta 0:00:0000:0100:01
# Downloading pynndescent-0.5.12-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 6.8 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 4.8 MB/s eta 0:00:00a 0:00:01
# Downloading statsmodels-0.14.2-cp310-cp310-macosx_10_9_x86_64.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 3.6 MB/s eta 0:00:0000:0100:01
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 4.5 MB/s eta 0:00:00
# Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 4.3 MB/s eta 0:00:00
# Downloading array_api_compat-1.6-py3-none-any.whl (36 kB)
# Downloading contourpy-1.2.1-cp310-cp310-macosx_10_9_x86_64.whl (260 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.8/260.8 kB 4.1 MB/s eta 0:00:00a 0:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp310-cp310-macosx_10_9_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.5-cp310-cp310-macosx_10_9_x86_64.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 4.9 MB/s eta 0:00:00
# Downloading llvmlite-0.42.0-cp310-cp310-macosx_10_9_x86_64.whl (31.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.1/31.1 MB 3.1 MB/s eta 0:00:0000:0100:01
# Downloading pillow-10.3.0-cp310-cp310-macosx_10_10_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 3.1 MB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 3.3 MB/s eta 0:00:00
# Downloading stdlib_list-0.10.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 3.9 MB/s eta 0:00:00
# Building wheels for collected packages: session-info
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8047 sha256=36b3d24f61478ea450425709755ee05738b348ccb11d4fa9630560ead5828c33
#   Stored in directory: /private/var/folders/gy/4gnqvn_j2tdc7h94m6vb8dd40000gp/T/pip-ephem-wheel-cache-ji3touyg/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built session-info
# Installing collected packages: array-api-compat, tqdm, stdlib_list, pyparsing, pillow, patsy, networkx, natsort, llvmlite, legacy-api-wrap, kiwisolver, h5py, fonttools, cycler, contourpy, session-info, numba, matplotlib, statsmodels, seaborn, pynndescent, anndata, umap-learn, scanpy
# Successfully installed anndata-0.10.7 array-api-compat-1.6 contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 h5py-3.11.0 kiwisolver-1.4.5 legacy-api-wrap-1.4 llvmlite-0.42.0 matplotlib-3.8.4 natsort-8.4.0 networkx-3.3 numba-0.59.1 patsy-0.5.6 pillow-10.3.0 pynndescent-0.5.12 pyparsing-3.1.2 scanpy-1.10.1 seaborn-0.13.2 session-info-1.0.0 statsmodels-0.14.2 stdlib_list-0.10.0 tqdm-4.66.2 umap-learn-0.5.6
# Collecting gseapy
#   Downloading gseapy-1.1.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.13.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gseapy) (1.24.3)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gseapy) (1.13.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gseapy) (2.2.2)
# Requirement already satisfied: matplotlib>=2.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gseapy) (3.8.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gseapy) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=2.2->gseapy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=2.2->gseapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=2.2->gseapy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=2.2->gseapy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from matplotlib>=2.2->gseapy) (23.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=2.2->gseapy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=2.2->gseapy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from matplotlib>=2.2->gseapy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas->gseapy) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas->gseapy) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->gseapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->gseapy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests->gseapy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests->gseapy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->gseapy) (1.16.0)
# Downloading gseapy-1.1.2-cp310-cp310-macosx_10_9_x86_64.whl (510 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 1.0 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: gseapy
# Successfully installed gseapy-1.1.2
# Collecting pydeseq2
#   Downloading pydeseq2-0.4.8-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: anndata>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydeseq2) (0.10.7)
# Requirement already satisfied: numpy>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydeseq2) (1.24.3)
# Requirement already satisfied: pandas>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydeseq2) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydeseq2) (1.4.2)
# Requirement already satisfied: scipy>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydeseq2) (1.13.0)
# Requirement already satisfied: matplotlib>=3.6.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydeseq2) (3.8.4)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anndata>=0.8.0->pydeseq2) (1.6)
# Requirement already satisfied: exceptiongroup in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anndata>=0.8.0->pydeseq2) (1.2.1)
# Requirement already satisfied: h5py>=3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anndata>=0.8.0->pydeseq2) (3.11.0)
# Requirement already satisfied: natsort in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anndata>=0.8.0->pydeseq2) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from anndata>=0.8.0->pydeseq2) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pydeseq2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from matplotlib>=3.6.2->pydeseq2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas>=1.4.0->pydeseq2) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.4.0->pydeseq2) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn>=1.1.0->pydeseq2) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn>=1.1.0->pydeseq2) (3.4.0)
# Requirement already satisfied: six>=1.5 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->pydeseq2) (1.16.0)
# Downloading pydeseq2-0.4.8-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 251.1 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: pydeseq2
# Successfully installed pydeseq2-0.4.8
# Collecting pybiomart==0.1
#   Downloading pybiomart-0.1.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: future in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pybiomart==0.1) (1.0.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pybiomart==0.1) (2.2.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pybiomart==0.1) (2.31.0)
# Requirement already satisfied: requests_cache in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pybiomart==0.1) (1.2.0)
# Requirement already satisfied: numpy>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas->pybiomart==0.1) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas->pybiomart==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas->pybiomart==0.1) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas->pybiomart==0.1) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->pybiomart==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->pybiomart==0.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests->pybiomart==0.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests->pybiomart==0.1) (2023.7.22)
# Requirement already satisfied: attrs>=21.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests_cache->pybiomart==0.1) (23.2.0)
# Requirement already satisfied: cattrs>=22.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests_cache->pybiomart==0.1) (23.2.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests_cache->pybiomart==0.1) (3.5.1)
# Requirement already satisfied: url-normalize>=1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests_cache->pybiomart==0.1) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cattrs>=22.2->requests_cache->pybiomart==0.1) (1.2.1)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cattrs>=22.2->requests_cache->pybiomart==0.1) (4.11.0)
# Requirement already satisfied: six>=1.5 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas->pybiomart==0.1) (1.16.0)
# Building wheels for collected packages: pybiomart
#   Building wheel for pybiomart (setup.py) ... done
#   Created wheel for pybiomart: filename=pybiomart-0.1-py3-none-any.whl size=14607 sha256=224c0e61007a28538d0d757d9e24ca03897da6c538c510c8ed16bc924cfb978a
#   Stored in directory: /private/var/folders/gy/4gnqvn_j2tdc7h94m6vb8dd40000gp/T/pip-ephem-wheel-cache-09at9qsv/wheels/b3/07/8b/21153224936c782146a686de88b58e1d177b8873104b601ff7
# Successfully built pybiomart
# Installing collected packages: pybiomart
#   Attempting uninstall: pybiomart
#     Found existing installation: pybiomart 0.2.0
#     Uninstalling pybiomart-0.2.0:
#       Successfully uninstalled pybiomart-0.2.0
# Successfully installed pybiomart-0.1
# Collecting mygene
#   Downloading mygene-3.2.2-py2.py3-none-any.whl.metadata (10 kB)
# Collecting biothings-client>=0.2.6 (from mygene)
#   Downloading biothings_client-0.3.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: requests>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from biothings-client>=0.2.6->mygene) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (2023.7.22)
# Downloading mygene-3.2.2-py2.py3-none-any.whl (5.4 kB)
# Downloading biothings_client-0.3.1-py2.py3-none-any.whl (29 kB)
# Installing collected packages: biothings-client, mygene
# Successfully installed biothings-client-0.3.1 mygene-3.2.2
# Collecting sklearn_som
#   Downloading sklearn_som-1.1.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sklearn_som) (1.24.3)
# Downloading sklearn_som-1.1.0-py3-none-any.whl (6.7 kB)
# Installing collected packages: sklearn_som
# Successfully installed sklearn_som-1.1.0
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.24.3)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sklearn-som in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sklearn-som) (1.24.3)
# Requirement already satisfied: pyDeseq2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.4.8)
# Requirement already satisfied: anndata>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyDeseq2) (0.10.7)
# Requirement already satisfied: numpy>=1.23.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyDeseq2) (1.24.3)
# Requirement already satisfied: pandas>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyDeseq2) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyDeseq2) (1.4.2)
# Requirement already satisfied: scipy>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyDeseq2) (1.13.0)
# Requirement already satisfied: matplotlib>=3.6.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyDeseq2) (3.8.4)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anndata>=0.8.0->pyDeseq2) (1.6)
# Requirement already satisfied: exceptiongroup in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anndata>=0.8.0->pyDeseq2) (1.2.1)
# Requirement already satisfied: h5py>=3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anndata>=0.8.0->pyDeseq2) (3.11.0)
# Requirement already satisfied: natsort in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from anndata>=0.8.0->pyDeseq2) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from anndata>=0.8.0->pyDeseq2) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pyDeseq2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pyDeseq2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pyDeseq2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pyDeseq2) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pyDeseq2) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.6.2->pyDeseq2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from matplotlib>=3.6.2->pyDeseq2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas>=1.4.0->pyDeseq2) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.4.0->pyDeseq2) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn>=1.1.0->pyDeseq2) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn>=1.1.0->pyDeseq2) (3.4.0)
# Requirement already satisfied: six>=1.5 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->pyDeseq2) (1.16.0)
# Collecting Ensembl_converter
#   Downloading ensembl_converter-0.0.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Ensembl_converter) (1.24.3)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Ensembl_converter) (2.2.2)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Ensembl_converter) (4.66.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from Ensembl_converter) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas->Ensembl_converter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from pandas->Ensembl_converter) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas->Ensembl_converter) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->Ensembl_converter) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->Ensembl_converter) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests->Ensembl_converter) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests->Ensembl_converter) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas->Ensembl_converter) (1.16.0)
# Downloading ensembl_converter-0.0.1-py3-none-any.whl (4.3 kB)
# Installing collected packages: Ensembl_converter
# Successfully installed Ensembl_converter-0.0.1
# Requirement already satisfied: mygene in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (3.2.2)
# Requirement already satisfied: biothings-client>=0.2.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mygene) (0.3.1)
# Requirement already satisfied: requests>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from biothings-client>=0.2.6->mygene) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rjbarker/Library/Python/3.10/lib/python/site-packages (from requests>=2.3.0->biothings-client>=0.2.6->mygene) (2023.7.22)

# %% [markdown]
# # import Python modules

# %% [markdown]
# This notebook imports a number of Python modules for use in several notebooks.

# %%
import requests
import json
import pandas as pd
from urllib.request import urlretrieve
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn_som.som import SOM
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import scanpy as sc
import gseapy as gp
from gseapy.plot import gseaplot
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
from gseapy import Msigdb
import mygene
import seaborn as sns
from sklearn.decomposition import PCA, FastICA
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn import linear_model
from sklearn.linear_model import TweedieRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
from math import log
import statsmodels.api as sm
import pylab
import operator
from sklearn.mixture import GaussianMixture
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
from sklearn.inspection import permutation_importance
from itertools import islice
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import argparse
import scipy.stats as stats
from sklearn.inspection import permutation_importance
import warnings
warnings.filterwarnings('ignore')
from Ensembl_converter import EnsemblConverter

# %%
from pybiomart import Server
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from pybiomart import Server
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pybiomart/__init__.py:1
# ----> 1 from .server import Server
#       2 from .mart import Mart
#       3 from .dataset import Dataset
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pybiomart/server.py:12
#       9 import pandas as pd
#      11 # pylint: disable=import-error
# ---> 12 from .base import ServerBase
#      13 from .mart import Mart
#      14 # pylint: enable=import-error
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pybiomart/base.py:15
#      12 DEFAULT_PORT = 80
#      13 DEFAULT_SCHEMA = 'default'
# ---> 15 requests_cache.install_cache('_pybiomart_cache')
#      18 class ServerBase(object):
#      20     """Base class that handles requests to the biomart server.
#      21
#      22     Attributes:
#    (...)
#      28
#      29     """
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests_cache/patcher.py:41, in install_cache(cache_name, backend, session_factory, **kwargs)
#      22 def install_cache(
#      23     cache_name: str = 'http_cache',
#      24     backend: Optional[BackendSpecifier] = None,
#      25     session_factory: Type[OriginalSession] = CachedSession,
#      26     **kwargs,
#      27 ):
#      28     """
#      29     Install the cache for all ``requests`` functions by monkey-patching :py:class:`requests.Session`
#      30
#    (...)
#      39             :py:class:`.CachedSession` or :py:class:`.CacheMixin`
#      40     """
# ---> 41     backend = init_backend(cache_name, backend, **kwargs)
#      43     class _ConfiguredCachedSession(session_factory):  # type: ignore  # See mypy issue #5865
#      44         def __init__(self):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests_cache/backends/__init__.py:91, in init_backend(cache_name, backend, **kwargs)
#      86 if backend not in BACKEND_CLASSES:
#      87     raise ValueError(
#      88         f'Invalid backend: {backend}. Provide a backend instance, or choose from one of the '
#      89         f'following aliases: {list(BACKEND_CLASSES.keys())}'
#      90     )
# ---> 91 return BACKEND_CLASSES[backend](cache_name, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests_cache/backends/sqlite.py:61, in SQLiteCache.__init__(self, db_path, serializer, **kwargs)
#      59 # Only override serializer if a non-None value is specified
#      60 skwargs = {'serializer': serializer, **kwargs} if serializer else kwargs
# ---> 61 self.responses: SQLiteDict = SQLiteDict(db_path, table_name='responses', **skwargs)
#      62 self.redirects: SQLiteDict = SQLiteDict(
#      63     db_path,
#      64     table_name='redirects',
#    (...)
#      67     **kwargs,
#      68 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests_cache/backends/sqlite.py:225, in SQLiteDict.__init__(self, db_path, table_name, busy_timeout, fast_save, retries, serializer, use_cache_dir, use_memory, use_temp, wal, **kwargs)
#     223 self.table_name = table_name
#     224 self.wal = wal
# --> 225 self.init_db()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests_cache/backends/sqlite.py:230, in SQLiteDict.init_db(self)
#     228 """Initialize the database, if it hasn't already been"""
#     229 self.close()
# --> 230 with self.connection(commit=True) as con:
#     231     # Add new column to tables created before 1.0
#     232     try:
#     233         con.execute(f'ALTER TABLE {self.table_name} ADD COLUMN expires INTEGER')
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests_cache/backends/sqlite.py:252, in SQLiteDict.connection(self, commit)
#     250 if not self._connection:
#     251     logger.debug(f'Opening connection to {self.db_path}:{self.table_name}')
# --> 252     self._connection = sqlite3.connect(self.db_path, **self.connection_kwargs)
#     253     # Note: DBAPI doesn't support integer placeholders
#     254     if self.busy_timeout is not None:
#
# OperationalError: unable to open database file

# %%
import sqlite3
print(sqlite3.version)
# Out:
# 2.6.0

# %%
ls -l
# Out:
# total 9
# drwxrwxr-x  44 root  admin  1408 Apr 20 18:04 Applications/
# drwxr-xr-x  71 root  wheel  2272 Apr 14 07:15 Library/
# drwxr-xr-x@ 10 root  wheel   320 Mar 21 01:13 System/
# drwxr-xr-x   7 root  admin   224 Apr 12 08:34 Users/
# drwxr-xr-x   4 root  wheel   128 Apr 22 09:59 Volumes/
# drwxr-xr-x@ 39 root  wheel  1248 Mar 21 01:13 bin/
# drwxr-xr-x   2 root  wheel    64 Apr  1  2023 cores/
# dr-xr-xr-x   3 root  wheel  4560 Apr 21 07:30 dev/
# lrwxr-xr-x@  1 root  wheel    11 Mar 21 01:13 etc@ -> private/etc
# lrwxr-xr-x   1 root  wheel    25 Apr 21 07:30 home@ -> /System/Volumes/Data/home
# drwxr-xr-x   6 root  wheel   192 Aug 30  2023 opt/
# drwxr-xr-x   6 root  wheel   192 Apr 21 07:30 private/
# drwxr-xr-x@ 64 root  wheel  2048 Mar 21 01:13 sbin/
# lrwxr-xr-x@  1 root  wheel    11 Mar 21 01:13 tmp@ -> private/tmp
# drwxr-xr-x@ 11 root  wheel   352 Mar 21 01:13 usr/
# lrwxr-xr-x@  1 root  wheel    11 Mar 21 01:13 var@ -> private/var

# %% [markdown]
# # define misc helper methods

# %%
def set_maxdisplay(n=None):
  pd.set_option('display.max_rows', n)
  from notebook.services.config import ConfigManager
  cm = ConfigManager().update('notebook', {'limit_output': n})

# %% [markdown]
# # Define data ingestion methods

# %%
def read_meta_data(dataset):
  # dataset=255
  url = 'https://osdr.nasa.gov/geode-py/ws/studies/OSD-' + str(dataset) + '/download?source=datamanager&file=OSD-' + dataset + '_metadata_OSD-' + dataset + '-ISA.zip'
  filename = dataset + '-meta.zip'
  urlretrieve(url, filename)
  # !unzip -o {filename} > /dev/null
  df = pd.read_csv('s_OSD-' + dataset + '.txt', sep='\t', header=0)
  return df

# %%
def read_rnaseq_data(data):
  # data = '255_rna_seq_Normalized_Counts'
  dataset = data.split('_')[0]
  url='https://osdr.nasa.gov/geode-py/ws/studies/OSD-' + str(dataset) + '/download?source=datamanager&file=GLDS-' + data + '.csv'
  df = pd.read_csv(url)
  return df

# %%
def read_phenotype_data(dataset, data):
  # dataset = '557'
  # data = 'LSDS-1_immunostaining_microscopy_PNAtr_Transformed_Reusable_Results'
  url='https://osdr.nasa.gov//geode-py/ws/studies/OSD-' + str(dataset) + '/download?source=datamanager&file=' + data + '.csv'
  df = pd.read_csv(url)
  return df

# %% [markdown]
# # define data filtering methods

# %%
def filter_cvs(df, thresh=0.5):

  # calculate coefficient of variation
  cvs=list()
  for i in range(len(df)):
    m=np.mean(df.iloc[i][1:])
    sd=np.std(df.iloc[i][1:])
    cvs.append(sd/m)

  # plot hist of dist of coev of variation
  fig, axs = plt.subplots()
  axs.hist(cvs, bins=20)

  # keep genes with cv > thresh
  indices = list()
  for i in range(len(cvs)):
    if cvs[i] > thresh:
      indices.append(i)
  return df.iloc[indices]

# %%
def drop_nans(df):
  # drop NaN rows
  df.dropna(inplace=True)
  return df

# %%
def drop_lowcount(df, threshold=10):

  # let's drop any low-count genes
  print(len(df))
  if 'transcript' in df.columns:
    df = df[df.drop(columns=['transcript']).sum(axis=1) >= threshold]
  elif 'Unnamed: 0' in df.columns:
    df = df[df.drop(columns=['Unnamed: 0']).sum(axis=1) >= threshold]
    df.rename(columns={"Unnamed: 0":"transcript"}, inplace=True)
  else:
    raise Exception("check file format")
  return df

# %%
def filter_genes(df, drop='non-coding'):
  # let's filter protein/ non-protein-coding genes
  if drop is None:
    return df
  server = Server(host='http://www.ensembl.org')
  dataset = (server.marts['ENSEMBL_MART_ENSEMBL'].datasets['mmusculus_gene_ensembl'])
  gene_info = dataset.query(attributes=['ensembl_gene_id', 'external_gene_name', 'gene_biotype'])
  if drop=='non-coding':
    filter_genes=gene_info[gene_info['Gene type'] == 'protein_coding']['Gene stable ID']
  elif drop=='coding':
    filter_genes=gene_info[gene_info['Gene type'] != 'protein_coding']['Gene stable ID']
  else:
    return df
  df=df[df['Unnamed: 0'].isin(filter_genes)]
  return df

# %%
def filter_data(df, dropnans=False, dropgenes='non-coding', droplowcvs=0):
  # drop NANs
  if dropnans:
    df = drop_nans(df)
  # drop non protein-coding genes
  if not dropgenes is None:
    df = filter_genes(df, drop=dropgenes)
  # drop low coef of var genes
  if droplowcvs != 0:
    df = filter_cvs(df, droplowcvs)
  return df

# %%
def exclude_samples_by_prefix(df, prefix="V", colname="Source Name"):
  sample_names=list(df[colname].values)
  exclude_names=list()
  for sn in sample_names:
    if sn.startswith(prefix):
      exclude_names.append(sn)
  return exclude_names

# %% [markdown]
# # data transformation methods

# %%
def transpose_df(df, cur_index_col, new_index_col):
  df = df.set_index(cur_index_col).T
  df.reset_index(level=0, inplace=True)
  cols = [new_index_col] + list(df.columns)[1:]
  df.columns = cols
  return df

# %%
def reduce_dims(df, current_key, new_key, n):
  #df_t = transpose_df(df, current_key, new_key)
  #sdList = df_t.var(axis=1)
  sdList = df.std(axis=1)
  print('len of sdlist: ', str(len(sdList)))
  sdDict = {k: v for v, k in enumerate(sdList)}
  if n < 0:
    sdDictSorted = sorted(sdDict.items(), key=operator.itemgetter(0), reverse=False)
  else:
    sdDictSorted = sorted(sdDict.items(), key=operator.itemgetter(0), reverse=True)
  topN = sdDictSorted[0:abs(n)]
  print('n: ', n)
  indices = [x[1] for x in topN]
  #df_t = df_t.iloc[indices]
  #df_tt= transpose_df(df_t, new_key, current_key)
  return df.iloc[indices]

# %%
def convert_pd_to_np(df):
  X=list()
  for col in df.columns[1:]:
    X.append(list(df[col]))
  return np.array(X)

# %%
def get_symbol_from_id(gene_id_list):
  # Create an instance of EnsemblConverter
  converter = EnsemblConverter()

  # Convert Ensembl IDs to gene symbols
  result = converter.convert_ids(gene_id_list)

  # Print the resulting DataFrame
  gene_symbol_list = list()
  for i in range(len(result)):
    gene_symbol_list.append(result.iloc[i]['Symbol'])

  return gene_symbol_list

# %% [markdown]
# # plotting methods

# %%
def plotbox_and_stats(data_, sample_key, field, treatment, space, exclude_samples=[]):
  print('field: ', field)
  print('excluding samples: ', exclude_samples)
  fieldValues = set(data_[field])
  value_dict=dict()
  results = dict()

  flight = str(field) + '_flight'
  nonflight= str(field) + '_nonflight'
  results[field] = dict()
  value_dict[flight] = list()
  value_dict[nonflight] = list()
  for i in range(len(data_)):
    if data_.iloc[i][sample_key] in exclude_samples:
      continue
    elif treatment is None:
      if data_.iloc[i][sample_key].startswith('F'):
        value_dict[flight].append(data_.iloc[i][field])
      else:
        value_dict[nonflight].append(data_.iloc[i][field])
    else:
      if data_.iloc[i][treatment] == space:
        value_dict[flight].append(data_.iloc[i][field])
      else:
        value_dict[nonflight].append(data_.iloc[i][field])


  if len(value_dict[flight]) != 0 and len(value_dict[nonflight]) != 0:
    results[field]['t-test p-value'] = float('%.5f' % (stats.ttest_ind(value_dict[flight], value_dict[nonflight], equal_var=False).pvalue))
    results[field]['wilcoxon p-value'] = float('%.5f' % (stats.ranksums(value_dict[flight], value_dict[nonflight]).pvalue))
    results[field]['ks-test p-value'] = float('%.5f' % (stats.kstest(value_dict[flight], value_dict[nonflight]).pvalue))


  print(results)
  print('n flight = ', len(value_dict[flight]))
  print('n nonflight = ', len(value_dict[nonflight]))
  fig,ax = plt.subplots()
  ax.boxplot(value_dict.values())
  ax.set_xticklabels(value_dict.keys())
  #plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
  plt.xticks(rotation=30, ha='right')



  plt.show()

# %% [markdown]
# # machine learning methods

# %%
# define a method to run the k-means algorithm and then print which cluster each sample belongs to
def my_kmeans(df, metadata, k):
  # convert df to np
  X = convert_pd_to_np(df)
  kmeans = KMeans(n_clusters=k, random_state=42, init="k-means++").fit(X)
  # and predict each sample
  samples = df.columns[1:]
  for sample in samples:
    print('sample: ', sample, ', cluster: ', kmeans.predict([list(df[sample])]), metadata['255'][metadata['255']['Sample Name']==sample]['Factor Value[Spaceflight]'].values[0])

# %%
# define a method that graphs the within-cluster-sum-of-squares metric to determine the optimum value of k (the elbow method)
def find_k_elbow(df):
  # convert df to np
  X = convert_pd_to_np(df)
  wcss = []
  for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42, n_init=i)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

  # plot wcss
  x=[i for i in range(1, 11)]
  y=wcss

  plt.scatter(x, y)

# %%
def my_gmm(df, metadata, k):
  # convert df to np
  #df=data['255-normalized']
  X = convert_pd_to_np(df)
  gm = GaussianMixture(n_components=k, random_state=42).fit(X)
  # and predict each sample
  samples = df.columns[1:]
  # predict probability
  for sample in samples:
    print('sample: ', sample, ', cluster: ', gm.predict([list(df[sample])]), metadata['255'][metadata['255']['Sample Name']==sample]['Factor Value[Spaceflight]'].values[0])
  return gm

# %%
def find_gmm_elbow(df):
  X = convert_pd_to_np(df)
  n_components=range(1, 11)
  models = [GaussianMixture(n, n_init=42).fit(X) for n in n_components]
  aics = [model.aic(X) for model in models]
  bics = [model.bic(X) for model in models]
  plt.figure(dpi=100)
  plt.plot(n_components, aics, label='AIC')
  plt.plot(n_components, bics, label='BIC')
  plt.legend(loc='best')
  plt.xlabel('n_components')
  plt.ylabel('AIC or BIC')
  plt.show()

# %% [markdown]
# # Differential gene expression analysis methods

# %%
def map_samples_to_conditions(dfT, metadata, metadata_condition_param, condition_0, condition_1):
  # map conditions to samples for comparison in DESeq2
  condition_dict=dict()
  for sample in list(dfT['sample']):
    #val=metadata['255'][metadata['255']['Sample Name']==sample]['Factor Value[Spaceflight]'].values[0]
    val=metadata[metadata['Sample Name']==sample][metadata_condition_param].values[0]

    if val == condition_0:
      condition_dict[sample] = 0
    else:
      condition_dict[sample] = 1


  dfT["condition"] = dfT["sample"].map(condition_dict)
  conditions=dfT[['sample', 'condition']]

  return conditions

# %%
def run_deseq2(df, metadata):
  # transpose df
  dfT = df.T
  dfT.columns=dfT.iloc[0]
  dfT=dfT.iloc[1:]
  dfT.columns.name=None
  dfT = dfT.reset_index().rename(columns={"index":"sample"})

  # map conditions
  conditions = map_samples_to_conditions(dfT, metadata, 'Factor Value[Spaceflight]', 'Ground Control', 'Space Flight')

  # get count data set up for DESeq2
  counts=dfT.drop(columns=['sample', 'condition']).reset_index(drop=True)
  counts.applymap(np.isreal)
  counts=counts.astype(int)

  # run DESeq2
  dds=DeseqDataSet(counts=counts, metadata=conditions, design_factors="condition")
  dds.deseq2()

  return dds

# %%
def get_results(dds):
  # do DGEA
  stats_results=DeseqStats(dds, contrast = ('condition', '0', '1'))

  # run summary
  stats_results.summary()

  # get differentially expressed genes
  res = stats_results.results_df

  return res

# %%
def get_sig_genes(res, pval=0.05, l2fc=0):
  sigs = res[(res.padj < pval) & (abs(res.log2FoldChange) > l2fc)]
  return sigs

# %%
def get_dge_ranked_genes(res):
  # rank genes from most to least significantly differentially expressed
  ranking = res[['stat']].dropna().sort_values('stat', ascending=False)
  ranking_index=list(ranking.index)
  ranking_index_upper=[x.upper() for x in ranking_index]
  ranking.index=ranking_index_upper

  return ranking

# %%
def filter_by_dgea(data, metadata,  pval, l2fc):
  # run DESeq2
  dds = run_deseq2(data, metadata)

  # get results
  res = get_results(dds)

  # get sig genes
  sig_genes_df = get_sig_genes(res, pval=pval, l2fc=l2fc)

  # get top sig genes
  top_genes = list(sig_genes_df.sort_values('padj').index)

  # filter data by topn_genes
  return data[data['Unnamed: 0'].isin(top_genes)]
