# %% [markdown]
# # AI/ML methods notebook
#
# This notebook collects the AI/ML and bioinformatics methods used throughout the lessons, demonstrated on data from the CARA experiment (OSD-120), where *Arabidopsis thaliana* roots were grown in spaceflight (FLT) and on the ground as ground control (GC) aboard the International Space Station (Paul & Ferl). See https://osdr.nasa.gov/bio/repo/data/studies/OSD-120

# %% [markdown]
# # install Python packages
# This notebook is equipped with a dedicated login shell, tailored to the environment in which it is executed. If you are utilizing your personal compute system, such as a laptop, the login corresponds to your individual compute system login. Conversely, when running this notebook on Google Colab, the login is attributed to the root user. The initiation of Linux shell commands within Jupyter notebook code cells is denoted by a preceding exclamation point (!).
#
# In the code cell below, the provided pip commands are employed to install a range of Python libraries essential for the tasks covered in this notebook. It's worth noting that additional Python libraries are automatically installed within our virtual environment.

# %%
# !pip install scikit-learn --no-cache
# !pip install scanpy --no-cache
# !pip install gseapy --no-cache
# !pip install pydeseq2 --no-cache
# !pip install pybiomart --no-cache
# !pip install mygene --no-cache
# !pip install sklearn_som  --no-cache
# !pip install pandas --no-cache
# !pip install numpy --no-cache
# !pip install matplotlib --no-cache
# !pip install sklearn-som --no-cache
# !pip install pyDeseq2 --no-cache
# Out:
# Requirement already satisfied: scikit-learn in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scanpy in c:\users\drric\appdata\roaming\python\python313\site-packages (1.12.1)
# Requirement already satisfied: anndata>=0.10.8 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (0.12.18)
# Requirement already satisfied: certifi in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (2026.6.17)
# Requirement already satisfied: fast-array-utils>=1.4 in c:\users\drric\appdata\roaming\python\python313\site-packages (from fast-array-utils[accel,sparse]>=1.4->scanpy) (1.4.1)
# Requirement already satisfied: h5py>=3.11 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (3.16.0)
# Requirement already satisfied: joblib in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (1.5.3)
# Requirement already satisfied: legacy-api-wrap>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (1.5)
# Requirement already satisfied: matplotlib>=3.9 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (3.11.0)
# Requirement already satisfied: natsort in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in c:\users\drric\appdata\roaming\python\python313\site-packages (from scanpy) (3.6.1)
# Requirement already satisfied: numba>=0.60 in c:\users\drric\appdata\roaming\python\python313\site-packages (from scanpy) (0.65.1)
# Requirement already satisfied: numpy>=2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (2.2.6)
# Requirement already satisfied: packaging>=25 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (26.2)
# Requirement already satisfied: pandas>=2.3 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (2.3.3)
# Requirement already satisfied: patsy in c:\users\drric\appdata\roaming\python\python313\site-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in c:\users\drric\appdata\roaming\python\python313\site-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.6 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (1.9.0)
# Requirement already satisfied: scipy>=1.13 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (1.15.3)
# Requirement already satisfied: seaborn>=0.13.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scanpy) (0.4.1)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\drric\appdata\roaming\python\python313\site-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in c:\users\drric\appdata\roaming\python\python313\site-packages (from scanpy) (4.68.3)
# Requirement already satisfied: umap-learn>=0.5.12 in c:\users\drric\appdata\roaming\python\python313\site-packages (from scanpy) (0.5.12)
# Requirement already satisfied: array-api-compat>=1.7.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.10.8->scanpy) (1.15.0)
# Requirement already satisfied: scverse-misc>=0.0.3 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.10.8->scanpy) (0.1.1)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.10.8->scanpy) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.3->scanpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.3->scanpy) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.3->scanpy) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9->scanpy) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9->scanpy) (1.5.0)
# Requirement already satisfied: pillow>=9 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9->scanpy) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9->scanpy) (3.3.2)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in c:\users\drric\appdata\roaming\python\python313\site-packages (from numba>=0.60->scanpy) (0.47.0)
# Requirement already satisfied: six>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.3->scanpy) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.6->scanpy) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.6->scanpy) (3.6.0)
# Requirement already satisfied: donfig>=0.8 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (0.16.5)
# Requirement already satisfied: typing-extensions>=4.13 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (4.15.0)
# Requirement already satisfied: pyyaml in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->scanpy) (6.0.2)
# Requirement already satisfied: colorama in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from tqdm->scanpy) (0.4.6)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gseapy in c:\users\drric\appdata\roaming\python\python313\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.13.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from gseapy) (2.2.6)
# Requirement already satisfied: scipy in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from gseapy) (1.15.3)
# Requirement already satisfied: pandas in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from gseapy) (2.3.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from gseapy) (3.11.0)
# Requirement already satisfied: requests in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from gseapy) (2.34.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.2->gseapy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.2->gseapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.2->gseapy) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.2->gseapy) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.2->gseapy) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.2->gseapy) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.2->gseapy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=2.2->gseapy) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->gseapy) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas->gseapy) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas->gseapy) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests->gseapy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests->gseapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests->gseapy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests->gseapy) (2026.6.17)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pydeseq2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (0.5.4)
# Requirement already satisfied: anndata>=0.11.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pydeseq2) (0.12.18)
# Requirement already satisfied: formulaic-contrasts>=0.2.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pydeseq2) (1.0.0)
# Requirement already satisfied: formulaic>=1.0.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pydeseq2) (1.2.2)
# Requirement already satisfied: matplotlib>=3.9.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pydeseq2) (3.11.0)
# Requirement already satisfied: numpy>=2.0.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pydeseq2) (2.2.6)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pydeseq2) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pydeseq2) (1.9.0)
# Requirement already satisfied: scipy>=1.12.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pydeseq2) (1.15.3)
# Requirement already satisfied: array-api-compat>=1.7.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pydeseq2) (1.15.0)
# Requirement already satisfied: h5py>=3.8 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pydeseq2) (3.16.0)
# Requirement already satisfied: legacy-api-wrap in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pydeseq2) (1.5)
# Requirement already satisfied: natsort in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pydeseq2) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pydeseq2) (26.2)
# Requirement already satisfied: scverse-misc>=0.0.3 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pydeseq2) (0.1.1)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pydeseq2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.2.0->pydeseq2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.2.0->pydeseq2) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.2.0->pydeseq2) (2026.2)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from formulaic>=1.0.2->pydeseq2) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from formulaic>=1.0.2->pydeseq2) (2.22.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from formulaic>=1.0.2->pydeseq2) (4.15.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from formulaic>=1.0.2->pydeseq2) (2.2.2)
# Requirement already satisfied: session-info in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from formulaic-contrasts>=0.2.0->pydeseq2) (1.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pydeseq2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pydeseq2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pydeseq2) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pydeseq2) (1.5.0)
# Requirement already satisfied: pillow>=9 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pydeseq2) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pydeseq2) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->pydeseq2) (1.17.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.4.0->pydeseq2) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.4.0->pydeseq2) (3.6.0)
# Requirement already satisfied: session-info2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scverse-misc>=0.0.3->anndata>=0.11.0->pydeseq2) (0.4.1)
# Requirement already satisfied: donfig>=0.8 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (0.16.5)
# Requirement already satisfied: pyyaml in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pydeseq2) (6.0.2)
# Requirement already satisfied: stdlib_list in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from session-info->formulaic-contrasts>=0.2.0->pydeseq2) (0.12.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pybiomart in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (0.2.0)
# Requirement already satisfied: future in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pybiomart) (1.0.0)
# Requirement already satisfied: pandas in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pybiomart) (2.3.3)
# Requirement already satisfied: requests in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pybiomart) (2.34.2)
# Requirement already satisfied: requests-cache in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pybiomart) (1.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas->pybiomart) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas->pybiomart) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas->pybiomart) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas->pybiomart) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas->pybiomart) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests->pybiomart) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests->pybiomart) (3.10)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests->pybiomart) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests->pybiomart) (2026.6.17)
# Requirement already satisfied: attrs>=21.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests-cache->pybiomart) (26.1.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests-cache->pybiomart) (26.1.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests-cache->pybiomart) (4.10.0)
# Requirement already satisfied: url-normalize>=2.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from requests-cache->pybiomart) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from cattrs>=22.2->requests-cache->pybiomart) (4.15.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: mygene in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (3.2.2)
# Requirement already satisfied: biothings-client>=0.2.6 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from mygene) (0.5.0)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from biothings-client>=0.2.6->mygene) (0.28.1)
# Requirement already satisfied: anyio in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (4.9.0)
# Requirement already satisfied: certifi in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (1.0.9)
# Requirement already satisfied: idna in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.0->biothings-client>=0.2.6->mygene) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->biothings-client>=0.2.6->mygene) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.25.0->biothings-client>=0.2.6->mygene) (1.3.1)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sklearn_som in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (1.1.0)
# Requirement already satisfied: numpy in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from sklearn_som) (2.2.6)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (2.2.6)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sklearn-som in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (1.1.0)
# Requirement already satisfied: numpy in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from sklearn-som) (2.2.6)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pyDeseq2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (0.5.4)
# Requirement already satisfied: anndata>=0.11.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pyDeseq2) (0.12.18)
# Requirement already satisfied: formulaic-contrasts>=0.2.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pyDeseq2) (1.0.0)
# Requirement already satisfied: formulaic>=1.0.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pyDeseq2) (1.2.2)
# Requirement already satisfied: matplotlib>=3.9.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pyDeseq2) (3.11.0)
# Requirement already satisfied: numpy>=2.0.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pyDeseq2) (2.2.6)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pyDeseq2) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pyDeseq2) (1.9.0)
# Requirement already satisfied: scipy>=1.12.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pyDeseq2) (1.15.3)
# Requirement already satisfied: array-api-compat>=1.7.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pyDeseq2) (1.15.0)
# Requirement already satisfied: h5py>=3.8 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pyDeseq2) (3.16.0)
# Requirement already satisfied: legacy-api-wrap in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pyDeseq2) (1.5)
# Requirement already satisfied: natsort in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pyDeseq2) (8.4.0)
# Requirement already satisfied: packaging>=24.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pyDeseq2) (26.2)
# Requirement already satisfied: scverse-misc>=0.0.3 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pyDeseq2) (0.1.1)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from anndata>=0.11.0->pyDeseq2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.2.0->pyDeseq2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.2.0->pyDeseq2) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.2.0->pyDeseq2) (2026.2)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from formulaic>=1.0.2->pyDeseq2) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from formulaic>=1.0.2->pyDeseq2) (2.22.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from formulaic>=1.0.2->pyDeseq2) (4.15.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from formulaic>=1.0.2->pyDeseq2) (2.2.2)
# Requirement already satisfied: session-info in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from formulaic-contrasts>=0.2.0->pyDeseq2) (1.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pyDeseq2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pyDeseq2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pyDeseq2) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pyDeseq2) (1.5.0)
# Requirement already satisfied: pillow>=9 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pyDeseq2) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.9.0->pyDeseq2) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->pyDeseq2) (1.17.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.4.0->pyDeseq2) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.4.0->pyDeseq2) (3.6.0)
# Requirement already satisfied: session-info2 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from scverse-misc>=0.0.3->anndata>=0.11.0->pyDeseq2) (0.4.1)
# Requirement already satisfied: donfig>=0.8 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pyDeseq2) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pyDeseq2) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pyDeseq2) (0.16.5)
# Requirement already satisfied: pyyaml in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.11.0->pyDeseq2) (6.0.2)
# Requirement already satisfied: stdlib_list in c:\users\drric\appdata\local\programs\python\python313\lib\site-packages (from session-info->formulaic-contrasts>=0.2.0->pyDeseq2) (0.12.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # import Python modules

# %% [markdown]
# This notebook imports a number of Python modules for use in several notebooks.

# %%
import requests
import json
import pandas as pd
from urllib.request import urlretrieve
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn_som.som import SOM
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import scanpy as sc
import gseapy as gp
from gseapy.plot import gseaplot
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
from gseapy import Msigdb
from pybiomart import Server, Dataset
import mygene
import seaborn as sns
from sklearn.decomposition import PCA, FastICA
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn import linear_model
from sklearn.linear_model import TweedieRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
from math import log
import statsmodels.api as sm
import pylab
import operator
from sklearn.mixture import GaussianMixture
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn.neural_network import MLPClassifier
from sklearn.inspection import permutation_importance
from itertools import islice
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # define misc helper methods

# %%
def set_maxdisplay(n=None):
  pd.set_option('display.max_rows', n)
  from notebook.services.config import ConfigManager
  cm = ConfigManager().update('notebook', {'limit_output': n})

# %% [markdown]
# # Define data ingestion methods

# %%
def read_meta_data(dataset):
  # dataset=120
  url = 'https://osdr.nasa.gov/geode-py/ws/studies/OSD-' + str(dataset) + '/download?source=datamanager&file=OSD-' + dataset + '_metadata_OSD-' + dataset + '-ISA.zip'
  filename = dataset + '-meta.zip'
  urlretrieve(url, filename)
  # !unzip -o {filename} > /dev/null
  df = pd.read_csv('s_OSD-' + dataset + '.txt', sep='\t', header=0)
  return df

# %%
def read_rnaseq_data(data):
  # data = '120_rna_seq_Normalized_Counts_GLbulkRNAseq'
  dataset = data.split('_')[0]
  url='https://osdr.nasa.gov/geode-py/ws/studies/OSD-' + str(dataset) + '/download?source=datamanager&file=GLDS-' + data + '.csv'
  df = pd.read_csv(url)
  return df

# %%
def read_phenotype_data(dataset, data):
  # dataset = '557'
  # data = 'LSDS-1_immunostaining_microscopy_PNAtr_Transformed_Reusable_Results'
  url='https://osdr.nasa.gov//geode-py/ws/studies/OSD-' + str(dataset) + '/download?source=datamanager&file=' + data + '.csv'
  df = pd.read_csv(url)
  return df

# %% [markdown]
# # define data filtering methods

# %%
def filter_cvs(df, frac=0.5):

  # calculate coefficient of variation
  cvs=list()
  for i in range(len(df)):
    m=np.mean(df.iloc[i][1:])
    sd=np.std(df.iloc[i][1:])
    cvs.append(sd/m)

  # plot hist of dist of coev of variation
  fig, axs = plt.subplots()
  axs.hist(cvs, bins=20)

  # keep genes with cv > frac
  indices = list()
  for i in range(len(cvs)):
    if cvs[i] > frac:
      indices.append(i)
  return df.iloc[indices]

# %%
def drop_nans(df):
  # drop NaN rows
  df.dropna(inplace=True)
  return df

# %%
def drop_lowcount(df, threshold=10):

  # let's drop any low-count genes
  print(len(df))
  if 'transcript' in df.columns:
    df = df[df.drop(columns=['transcript']).sum(axis=1) >= threshold]
  elif 'Unnamed: 0' in df.columns:
    df = df[df.drop(columns=['Unnamed: 0']).sum(axis=1) >= threshold]
    df.rename(columns={"Unnamed: 0":"transcript"}, inplace=True)
  else:
    raise Exception("check file format")
  return df

# %%
def filter_protein(df, drop='non-coding'):
  # let's filter protein/ non-protein-coding genes
  # CARA / OSD-120 uses Arabidopsis thaliana AGI loci (e.g. AT1G01010),
  # so we query the Ensembl Plants Arabidopsis dataset.
  dataset = Dataset(name='athaliana_eg_gene',
                    host='http://plants.ensembl.org',
                    virtual_schema='plants_mart')
  gene_info = dataset.query(attributes=['ensembl_gene_id', 'external_gene_name', 'gene_biotype'])
  if drop=='non-coding':
    filter_genes=gene_info[gene_info['Gene type'] == 'protein_coding']['Gene stable ID']
  elif drop=='coding':
    filter_genes=gene_info[gene_info['Gene type'] != 'protein_coding']['Gene stable ID']

  df=df[df['Unnamed: 0'].isin(filter_genes)]
  return df

# %%
def filter_data(df, dropnans=False, dropprotein='non-coding', droplowvar=0):
  # drop NANs
  if dropnans:
    df = drop_nans(df)
  # drop non protein-coding genes
  df = filter_protein(df, drop=dropprotein)
  # drop low variation genes
  if droplowvar != 0:
    df = filter_cvs(df, droplowvar)
  return df

# %%
def exclude_samples_by_prefix(df, prefix="V", colname="Source Name"):
  sample_names=list(df[colname].values)
  exclude_names=list()
  for sn in sample_names:
    if sn.startswith(prefix):
      exclude_names.append(sn)
  return exclude_names

# %% [markdown]
# # data transformation methods

# %%
def transpose_df(df, cur_index_col, new_index_col):
  df = df.set_index(cur_index_col).T
  df.reset_index(level=0, inplace=True)
  cols = [new_index_col] + list(df.columns)[1:]
  df.columns = cols
  return df

# %%
def reduce_dims(df, current_key, new_key, n):
  #df_t = transpose_df(df, current_key, new_key)
  #sdList = df_t.var(axis=1)
  sdList = df.std(axis=1)
  print('len of sdlist: ', str(len(sdList)))
  sdDict = {k: v for v, k in enumerate(sdList)}
  if n < 0:
    sdDictSorted = sorted(sdDict.items(), key=operator.itemgetter(0), reverse=False)
  else:
    sdDictSorted = sorted(sdDict.items(), key=operator.itemgetter(0), reverse=True)
  topN = sdDictSorted[0:abs(n)]
  print('n: ', n)
  indices = [x[1] for x in topN]
  #df_t = df_t.iloc[indices]
  #df_tt= transpose_df(df_t, new_key, current_key)
  return df.iloc[indices]

# %%
def convert_pd_to_np(df):
  X=list()
  for col in df.columns[1:]:
    X.append(list(df[col]))
  return np.array(X)

# %% [markdown]
# # plotting methods

# %%
import pandas as pd
import matplotlib.pyplot as plt
import argparse
import scipy.stats as stats

def plotbox_and_stats(data_, sample_key, field, treatment, space, exclude_samples=[]):
  print('field: ', field)
  print('excluding samples: ', exclude_samples)
  fieldValues = set(data_[field])
  value_dict=dict()
  results = dict()

  flight = str(field) + '_flight'
  nonflight= str(field) + '_nonflight'
  results[field] = dict()
  value_dict[flight] = list()
  value_dict[nonflight] = list()
  for i in range(len(data_)):
    if data_.iloc[i][sample_key] in exclude_samples:
      continue
    elif treatment is None:
      if data_.iloc[i][sample_key].startswith('F'):
        value_dict[flight].append(data_.iloc[i][field])
      else:
        value_dict[nonflight].append(data_.iloc[i][field])
    else:
      if data_.iloc[i][treatment] == space:
        value_dict[flight].append(data_.iloc[i][field])
      else:
        value_dict[nonflight].append(data_.iloc[i][field])


  if len(value_dict[flight]) != 0 and len(value_dict[nonflight]) != 0:
    results[field]['t-test p-value'] = float('%.5f' % (stats.ttest_ind(value_dict[flight], value_dict[nonflight]).pvalue))
    results[field]['wilcoxon p-value'] = float('%.5f' % (stats.ranksums(value_dict[flight], value_dict[nonflight]).pvalue))
    results[field]['ks-test p-value'] = float('%.5f' % (stats.kstest(value_dict[flight], value_dict[nonflight]).pvalue))


  print(results)
  print('n flight = ', len(value_dict[flight]))
  print('n nonflight = ', len(value_dict[nonflight]))
  fig,ax = plt.subplots()
  ax.boxplot(value_dict.values())
  ax.set_xticklabels(value_dict.keys())
  plt.show()
